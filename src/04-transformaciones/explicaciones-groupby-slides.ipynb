# %% [markdown]
# # Crear DataFrames agrupados
# `pandas` tiene una clase de objetos llamados `GroupedDataFrame` que permite agrupar las filas (o columnas) de un DataFrame.
#
# - Un ejemplo podría ser un conjunto de datos asociados a individuos para el que que queramos distinguir entre hombres y mujeres a la hora de calcular indicadores.
# - Otro caso podría ser el de mediciones asociadas a instantes de tiempo, y queremos calcular resúmenes para cada hora del día.
#
# Para crear dataframes agrupados, usaremos el método `groupby`. (ver [User guide, Group by: split-apply-combine](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html))

# %%
import pandas as pd
import numpy as np
from pathlib import Path
DATA_DIR = Path("..") / ".." / "data"

# %% [markdown]
# ## Consideremos el siguiente DataFrame:

# %%
df = pd.DataFrame(
    {
     "X": ['a', 'a', 'a', 'a', 'b', 'b', 'c', 'c'],
     "Y": np.arange(8),
     "Z": np.arange(8,16)
    }
)
df
# Out:
#    X  Y   Z
# 0  a  0   8
# 1  a  1   9
# 2  a  2  10
# 3  a  3  11
# 4  b  4  12
# 5  b  5  13
# 6  c  6  14
# 7  c  7  15

# %% [markdown]
# Agrupamos según los valores de la columna X

# %%
agrupados = df.groupby("X")
type(agrupados)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# Podemos iterar un `GroupedDataFrame` para recorrer los grupos:

# %%
for tag, grupo in agrupados:
    print(f"{tag}:\n{grupo}\n")
# Out:
# a:
#    X  Y   Z
# 0  a  0   8
# 1  a  1   9
# 2  a  2  10
# 3  a  3  11
#
# b:
#    X  Y   Z
# 4  b  4  12
# 5  b  5  13
#
# c:
#    X  Y   Z
# 6  c  6  14
# 7  c  7  15

# %% [markdown]
# Podemos aplicarle métodos preparados para `GroupedDataFrame` como `mean`, `sum` o `describe`

# %%
agrupados.sum()
# Out:
#     Y   Z
# X
# a   6  38
# b   9  25
# c  13  29

# %% [markdown]
# Nos devuelve el valor de la media por grupos de las dos columnas Y y Z.

# %%
agrupados.mean()
# Out:
#      Y     Z
# X
# a  1.5   9.5
# b  4.5  12.5
# c  6.5  14.5

# %%
agrupados.median()
# Out:
#      Y     Z
# X
# a  1.5   9.5
# b  4.5  12.5
# c  6.5  14.5

# %% [markdown]
# ## Podemos especificar más de una columna para crear los grupos.
#
# Para ilustrarlo, cargamos el DataFrame de `flights` que contiene todos los vuelos que salieron de los tres aeropuertos de NYC en 2013.

# %%
flights = pd.read_csv(
    DATA_DIR / "flights.csv",
    parse_dates=True,
)
flights
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 2                  850       33.0      AA    1141  N619AA    JFK  MIA
# 3                 1022      -18.0      B6     725  N804JB    JFK  BQN
# 4                  837      -25.0      DL     461  N668DN    LGA  ATL
# ...                ...        ...     ...     ...     ...    ...  ...
# 336771            1634        NaN      9E    3393     NaN    JFK  DCA
# 336772            2312        NaN      9E    3525     NaN    LGA  SYR
# 336773            1330        NaN      MQ    3461  N535MQ    LGA  BNA
# 336774            1344        NaN      MQ    3572  N511MQ    LGA  CLE
# 336775            1020        NaN      MQ    3531  N839MQ    LGA  RDU
#
#         air_time  distance  hour  minute                  time_hour
# 0          227.0    1400.0   5.0    15.0  2013-01-01 05:00:00-05:00
# 1          227.0    1416.0   5.0    29.0  2013-01-01 05:00:00-05:00
# 2          160.0    1089.0   5.0    40.0  2013-01-01 05:00:00-05:00
# 3          183.0    1576.0   5.0    45.0  2013-01-01 05:00:00-05:00
# 4          116.0     762.0   6.0     0.0  2013-01-01 06:00:00-05:00
# ...          ...       ...   ...     ...                        ...
# 336771       NaN     213.0  14.0    55.0  2013-09-30 14:00:00-04:00
# 336772       NaN     198.0  22.0     0.0  2013-09-30 22:00:00-04:00
# 336773       NaN     764.0  12.0    10.0  2013-09-30 12:00:00-04:00
# 336774       NaN     419.0  11.0    59.0  2013-09-30 11:00:00-04:00
# 336775       NaN     431.0   8.0    40.0  2013-09-30 08:00:00-04:00
#
# [336776 rows x 19 columns]

# %%
print(flights.columns)
print(flights.dtypes)
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour'],
#       dtype='object')
# year                int64
# month               int64
# day                 int64
# dep_time          float64
# sched_dep_time      int64
# dep_delay         float64
# arr_time          float64
# sched_arr_time      int64
# arr_delay         float64
# carrier            object
# flight              int64
# tailnum            object
# origin             object
# dest               object
# air_time          float64
# distance          float64
# hour              float64
# minute            float64
# time_hour          object
# dtype: object

# %%
# Cuantos vuelos en cada aeropuerto
flights["origin"].value_counts()
# Out:
# origin
# EWR    120835
# JFK    111279
# LGA    104662
# Name: count, dtype: int64

# %% [markdown]
# Agrupamos los vuelos para hacer recuentos desglosados por mes y por aeropuerto de origen

# %%
flights.groupby(["origin", "month"]).size()
# Out:
# origin  month
# EWR     1         9893
#         2         9107
#         3        10420
#         4        10531
#         5        10592
#         6        10175
#         7        10475
#         8        10359
#         9         9550
#         10       10104
#         11        9707
#         12        9922
# JFK     1         9161
#         2         8421
#         3         9697
#         4         9218
#         5         9397
#         6         9472
#         7        10023
#         8         9983
#         9         8908
#         10        9143
#         11        8710
#         12        9146
# LGA     1         7950
#         2         7423
#         3         8717
#         4         8581
#         5         8807
#         6         8596
#         7         8927
#         8         8985
#         9         9116
#         10        9642
#         11        8851
#         12        9067
# dtype: int64

# %% [markdown]
# Aplicamos el método `size` para hacer el recuento de filas (vuelos) por grupo:

# %%
agrupados.size()
# Out:
# X
# a    4
# b    2
# c    2
# dtype: int64

# %% [markdown]
# ## Podemos crear grupos al especificar una función que se aplica a los valores del index
#
# Para ilustrarlo, cargamos el fichero `mompean`

# %%
mompean = pd.read_csv(
    DATA_DIR / "mompean.csv",
    parse_dates=["FechaHora"],
    index_col=0
)
mompean
# Out:
#                        NO   NO2   SO2    O3  TMP  HR    NOX  DD  PRB  RS  VV  \
# FechaHora
# 2010-01-01 00:00:00   4.0   7.0  17.0   NaN  NaN NaN   14.0 NaN  NaN NaN NaN
# 2010-01-01 01:00:00   6.0  12.0  18.0   NaN  NaN NaN   21.0 NaN  NaN NaN NaN
# 2010-01-01 02:00:00   6.0  17.0  17.0   NaN  NaN NaN   26.0 NaN  NaN NaN NaN
# 2010-01-01 03:00:00   5.0  10.0  18.0   NaN  NaN NaN   18.0 NaN  NaN NaN NaN
# 2010-01-01 04:00:00   4.0   8.0  19.0   NaN  NaN NaN   14.0 NaN  NaN NaN NaN
# ...                   ...   ...   ...   ...  ...  ..    ...  ..  ...  ..  ..
# 2019-12-31 19:00:00   9.0  35.0   8.0  47.0  NaN NaN   49.0 NaN  NaN NaN NaN
# 2019-12-31 20:00:00  29.0  59.0   9.0  24.0  NaN NaN  102.0 NaN  NaN NaN NaN
# 2019-12-31 21:00:00  59.0  65.0   8.0  10.0  NaN NaN  155.0 NaN  NaN NaN NaN
# 2019-12-31 22:00:00  51.0  51.0   9.0  11.0  NaN NaN  130.0 NaN  NaN NaN NaN
# 2019-12-31 23:00:00  32.0  42.0   9.0   7.0  NaN NaN   90.0 NaN  NaN NaN NaN
#
#                      C6H6  C7H8  XIL  PM10  Ruido
# FechaHora
# 2010-01-01 00:00:00   NaN   NaN  NaN   5.0   56.0
# 2010-01-01 01:00:00   NaN   NaN  NaN  15.0   58.0
# 2010-01-01 02:00:00   NaN   NaN  NaN  12.0   60.0
# 2010-01-01 03:00:00   NaN   NaN  NaN   2.0   57.0
# 2010-01-01 04:00:00   NaN   NaN  NaN   5.0   55.0
# ...                   ...   ...  ...   ...    ...
# 2019-12-31 19:00:00   NaN   NaN  NaN  19.0    NaN
# 2019-12-31 20:00:00   NaN   NaN  NaN  41.0    NaN
# 2019-12-31 21:00:00   NaN   NaN  NaN  48.0    NaN
# 2019-12-31 22:00:00   NaN   NaN  NaN  45.0    NaN
# 2019-12-31 23:00:00   NaN   NaN  NaN  44.0    NaN
#
# [96408 rows x 16 columns]

# %% [markdown]
# Queremos crear grupos que correspondan a las distintas horas del día, para ver si hay diferencias en el patrón horario de contaminación.
#
# Para ello, pasamos a `groupby` una función que se aplique a las etiquetas de las filas (index) y que extraiga la hora de un objeto de tipo `dtime`

# %%
mompean.groupby(lambda x: x.hour).mean()
# Out:
#                   NO        NO2       SO2         O3  TMP  HR        NOX  DD  \
# FechaHora
# 0           9.618014  27.402604  7.516146  53.871709  NaN NaN  42.020890 NaN
# 1           7.779196  25.304997  7.399091  51.332306  NaN NaN  37.115698 NaN
# 2           6.599348  22.842077  7.323167  49.531390  NaN NaN  32.844795 NaN
# 3           4.858891  19.067700  7.234885  48.993829  NaN NaN  26.410005 NaN
# 4           4.147523  16.349483  7.184957  48.060045  NaN NaN  22.607512 NaN
# 5           4.095316  15.585240  7.150509  45.970250  NaN NaN  21.786220 NaN
# 6           5.992364  18.083174  7.177069  41.162830  NaN NaN  27.149168 NaN
# 7          12.616621  25.141144  7.252747  33.026404  NaN NaN  44.355586 NaN
# 8          18.700545  30.695095  7.376575  27.968004  NaN NaN  59.242234 NaN
# 9          34.211874  36.715686  7.711188  26.932959  NaN NaN  89.038399 NaN
# 10         26.159482  32.184573  7.810072  39.895430  NaN NaN  72.175290 NaN
# 11         13.300164  25.110716  7.697393  55.724283  NaN NaN  45.379716 NaN
# 12          9.329697  22.087810  7.825563  65.378219  NaN NaN  36.264249 NaN
# 13          8.356833  20.896150  7.995197  71.142339  NaN NaN  33.565618 NaN
# 14          7.735246  19.927721  8.148641  75.562849  NaN NaN  31.660531 NaN
# 15          7.167794  18.990257  8.609205  78.299637  NaN NaN  29.848714 NaN
# 16          6.474696  17.648714  8.834398  80.232617  NaN NaN  27.457645 NaN
# 17          6.404491  18.028950  9.035134  80.065624  NaN NaN  27.702922 NaN
# 18          6.553600  20.003249  9.063149  77.836409  NaN NaN  29.928803 NaN
# 19          7.001896  23.205038  8.684084  73.640817  NaN NaN  33.828548 NaN
# 20          8.330986  25.681203  8.342933  69.847144  NaN NaN  38.321506 NaN
# 21         10.382592  28.194685  7.983729  65.330907  NaN NaN  43.979393 NaN
# 22         11.746273  29.620222  7.777807  60.919373  NaN NaN  47.500678 NaN
# 23         12.008955  29.771235  7.646823  56.430933  NaN NaN  48.046676 NaN
#
#            PRB  RS  VV  C6H6  C7H8  XIL       PM10      Ruido
# FechaHora
# 0          NaN NaN NaN   NaN   NaN  NaN  24.416717  57.280031
# 1          NaN NaN NaN   NaN   NaN  NaN  22.790531  55.935533
# 2          NaN NaN NaN   NaN   NaN  NaN  21.687349  54.259800
# 3          NaN NaN NaN   NaN   NaN  NaN  20.119487  53.249424
# 4          NaN NaN NaN   NaN   NaN  NaN  18.802399  52.396618
# 5          NaN NaN NaN   NaN   NaN  NaN  17.874605  51.653077
# 6          NaN NaN NaN   NaN   NaN  NaN  17.907378  53.046959
# 7          NaN NaN NaN   NaN   NaN  NaN  20.484621  56.916923
# 8          NaN NaN NaN   NaN   NaN  NaN  24.919906  59.568129
# 9          NaN NaN NaN   NaN   NaN  NaN  32.868169  60.270978
# 10         NaN NaN NaN   NaN   NaN  NaN  34.702703  60.947096
# 11         NaN NaN NaN   NaN   NaN  NaN  29.696712  61.313124
# 12         NaN NaN NaN   NaN   NaN  NaN  27.035784  61.997703
# 13         NaN NaN NaN   NaN   NaN  NaN  25.787697  62.338168
# 14         NaN NaN NaN   NaN   NaN  NaN  24.944570  62.381679
# 15         NaN NaN NaN   NaN   NaN  NaN  23.915736  61.678380
# 16         NaN NaN NaN   NaN   NaN  NaN  23.579356  60.812404
# 17         NaN NaN NaN   NaN   NaN  NaN  24.367599  60.751149
# 18         NaN NaN NaN   NaN   NaN  NaN  24.708589  61.220352
# 19         NaN NaN NaN   NaN   NaN  NaN  24.993455  61.569678
# 20         NaN NaN NaN   NaN   NaN  NaN  25.506697  61.812261
# 21         NaN NaN NaN   NaN   NaN  NaN  26.555189  61.722265
# 22         NaN NaN NaN   NaN   NaN  NaN  26.788431  60.703675
# 23         NaN NaN NaN   NaN   NaN  NaN  25.949129  58.908046

# %% [markdown]
# Hemos usado una función anónima. Aplicamos el método `mean`

# %% [markdown]
# ## Podemos aplicar más de una función en `groupby`
#
# Pasamos una lista de funciones

# %%
mompean.groupby([lambda x: x.dayofweek, lambda x: x.hour]).mean()
# Out:
#                            NO        NO2       SO2         O3  TMP  HR  \
# FechaHora FechaHora
# 0         0          7.562380  25.581574  7.512287  55.924303  NaN NaN
#           1          6.180077  23.312261  7.435606  53.521912  NaN NaN
#           2          5.517241  21.136015  7.361742  51.169323  NaN NaN
#           3          4.126437  17.105364  7.229167  50.878486  NaN NaN
#           4          3.624521  14.111111  7.143939  50.537849  NaN NaN
# ...                       ...        ...       ...        ...  ...  ..
# 6         19         5.676245  18.860153  8.581132  77.117296  NaN NaN
#           20         6.545977  20.641762  8.330189  73.753479  NaN NaN
#           21         7.767754  23.921305  7.835539  68.711155  NaN NaN
#           22         8.694818  26.278311  7.667297  63.896414  NaN NaN
#           23         9.168906  27.220729  7.655955  59.272908  NaN NaN
#
#                            NOX  DD  PRB  RS  VV  C6H6  C7H8  XIL       PM10  \
# FechaHora FechaHora
# 0         0          37.084453 NaN  NaN NaN NaN   NaN   NaN  NaN  22.472486
#           1          32.668582 NaN  NaN NaN NaN   NaN   NaN  NaN  20.853890
#           2          29.501916 NaN  NaN NaN NaN   NaN   NaN  NaN  20.206831
#           3          23.373563 NaN  NaN NaN NaN   NaN   NaN  NaN  18.842505
#           4          19.616858 NaN  NaN NaN NaN   NaN   NaN  NaN  17.838710
# ...                        ...  ..  ...  ..  ..   ...   ...  ...        ...
# 6         19         27.421456 NaN  NaN NaN NaN   NaN   NaN  NaN  22.644612
#           20         30.588123 NaN  NaN NaN NaN   NaN   NaN  NaN  22.718336
#           21         35.700576 NaN  NaN NaN NaN   NaN   NaN  NaN  23.905303
#           22         39.462572 NaN  NaN NaN NaN   NaN   NaN  NaN  23.990512
#           23         41.084453 NaN  NaN NaN NaN   NaN   NaN  NaN  23.339658
#
#                          Ruido
# FechaHora FechaHora
# 0         0          57.027624
#           1          55.419890
#           2          53.508287
#           3          52.569061
#           4          51.806630
# ...                        ...
# 6         19         60.044199
#           20         60.364641
#           21         60.569061
#           22         59.972376
#           23         58.375691
#
# [168 rows x 16 columns]

# %% [markdown]
# Calculamos la media desglosada por grupo:

# %% [markdown]
# # Realizar operaciones sobre `GroupedDataFrame`s
#
# Podemos realizar tres tipos de operaciones que se traducen en tres verbos

# %% [markdown]
# - `aggregate`: se trata de resumir cada grupo calculando uno o varios indicadores, por ejemplo su media o su media y desviación típica
# - `transform`: se trata de calcular para cada grupo una o varias columnas con el mismo `index` que el grupo, por lo tanto con el mismo número de filas y las mismas etiquetas. Por ejemplo puedo, dentro de cada grupo, normalizar los valores respecto a la media y la desviación típica del grupo.
# - `filter`: se trata de seleccionar grupos  que cumplen un determinado criterio

# %% [markdown]
# Consideramos el DataFrame:

# %%
df = pd.DataFrame(
    {
        "X": ['a', 'a', 'a', 'a', 'b', 'b', 'c', 'c'], 
        "Y": np.arange(8),
        "Z": np.arange(8,16)
    }
)
df
# Out:
#    X  Y   Z
# 0  a  0   8
# 1  a  1   9
# 2  a  2  10
# 3  a  3  11
# 4  b  4  12
# 5  b  5  13
# 6  c  6  14
# 7  c  7  15

# %% [markdown]
# Agrupamos según los valores de `X` y aplicamos el método `agg`, pasándole la función para calcular el indicador.

# %%
df.groupby("X").agg(np.mean) # le pasamos una funcion en aggregate
# Out:
# /tmp/ipykernel_31322/1240945444.py:1: FutureWarning: The provided callable <function mean at 0x7f80d0d49620> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("X").agg(np.mean) # le pasamos una funcion en aggregate
#      Y     Z
# X
# a  1.5   9.5
# b  4.5  12.5
# c  6.5  14.5

# %%
df.groupby("X").agg([np.mean, "std"]) # le podemos pasar como txt una funcion de Pandas
# Out:
# /tmp/ipykernel_31322/1612061104.py:1: FutureWarning: The provided callable <function mean at 0x7f80d0d49620> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("X").agg([np.mean, "std"]) # le podemos pasar como txt una funcion de Pandas
# /tmp/ipykernel_31322/1612061104.py:1: FutureWarning: The provided callable <function mean at 0x7f80d0d49620> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("X").agg([np.mean, "std"]) # le podemos pasar como txt una funcion de Pandas
#      Y               Z
#   mean       std  mean       std
# X
# a  1.5  1.290994   9.5  1.290994
# b  4.5  0.707107  12.5  0.707107
# c  6.5  0.707107  14.5  0.707107

# %% [markdown]
# Ya vimos que se puede obtener el mismo resultado sin usar `agg`

# %% [markdown]
# Usar `agg` permite, por una parte, aplicar más de una función

# %% [markdown]
# Por otra parte, permite usar nuestras propias funciones.
#
# Para ilustrarlo, modificamos `df` para introducir datos faltantes

# %%
df.loc[[0, 2, 5], 'Y'] = np.NaN
df.loc[6, 'Z'] = np.NaN
df
# Out:
#    X    Y     Z
# 0  a  NaN   8.0
# 1  a  1.0   9.0
# 2  a  NaN  10.0
# 3  a  3.0  11.0
# 4  b  4.0  12.0
# 5  b  NaN  13.0
# 6  c  6.0   NaN
# 7  c  7.0  15.0

# %% [markdown]
# Calculamos el número de datos faltantes por columna, desglosándolo por grupos

# %%
df.groupby("X").agg(lambda x: x.isna().sum())
# Out:
#    Y  Z
# X
# a  2  0
# b  1  0
# c  0  1

# %% [markdown]
# Cargamos el conjunto de datos de vuelos que salieron en 2013 de uno de los tres aeropuertos de NYC

# %%
flights.groupby("hour").agg(lambda x: x.isna().sum())
# Out:
#       year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# hour
# 1.0      0      0    0         1               0          1         1
# 5.0      0      0    0         9               0          9         9
# 6.0      0      0    0       425               0        425       454
# 7.0      0      0    0       289               0        289       305
# 8.0      0      0    0       442               0        442       465
# 9.0      0      0    0       327               0        327       343
# 10.0     0      0    0       290               0        290       303
# 11.0     0      0    0       296               0        296       314
# 12.0     0      0    0       388               0        388       404
# 13.0     0      0    0       429               0        429       456
# 14.0     0      0    0       566               0        566       611
# 15.0     0      0    0       670               0        670       733
# 16.0     0      0    0       840               0        840       891
# 17.0     0      0    0       660               0        660       691
# 18.0     0      0    0       626               0        626       667
# 19.0     0      0    0       861               0        861       898
# 20.0     0      0    0       636               0        636       656
# 21.0     0      0    0       409               0        409       418
# 22.0     0      0    0        78               0         78        81
# 23.0     0      0    0        13               0         13        13
#
#       sched_arr_time  arr_delay  carrier  flight  tailnum  origin  dest  \
# hour
# 1.0                0          1        0       0        1       0     0
# 5.0                0         13        0       0        6       0     0
# 6.0                0        504        0       0      127       0     0
# 7.0                0        346        0       0      102       0     0
# 8.0                0        508        0       0      161       0     0
# 9.0                0        381        0       0      128       0     0
# 10.0               0        338        0       0       96       0     0
# 11.0               0        344        0       0       61       0     0
# 12.0               0        437        0       0       80       0     0
# 13.0               0        499        0       0       90       0     0
# 14.0               0        684        0       0      170       0     0
# 15.0               0        806        0       0      222       0     0
# 16.0               0        957        0       0      249       0     0
# 17.0               0        759        0       0      150       0     0
# 18.0               0        711        0       0      289       0     0
# 19.0               0        934        0       0      283       0     0
# 20.0               0        678        0       0      232       0     0
# 21.0               0        430        0       0       62       0     0
# 22.0               0         81        0       0        3       0     0
# 23.0               0         19        0       0        0       0     0
#
#       air_time  distance  minute  time_hour
# hour
# 1.0          1         0       0          0
# 5.0         13         0       0          0
# 6.0        504         0       0          0
# 7.0        346         0       0          0
# 8.0        508         0       0          0
# 9.0        381         0       0          0
# 10.0       338         0       0          0
# 11.0       344         0       0          0
# 12.0       437         0       0          0
# 13.0       499         0       0          0
# 14.0       684         0       0          0
# 15.0       806         0       0          0
# 16.0       957         0       0          0
# 17.0       759         0       0          0
# 18.0       711         0       0          0
# 19.0       934         0       0          0
# 20.0       678         0       0          0
# 21.0       430         0       0          0
# 22.0        81         0       0          0
# 23.0        19         0       0          0

# %% [markdown]
# Queremos obtener el número de vuelos cancelados por hora (tienen `NaN` en la columna `dep_time`)

# %%
flights.groupby("hour")["dep_time"].agg(lambda x: x.isna().sum())
# Out:
# hour
# 1.0       1
# 5.0       9
# 6.0     425
# 7.0     289
# 8.0     442
# 9.0     327
# 10.0    290
# 11.0    296
# 12.0    388
# 13.0    429
# 14.0    566
# 15.0    670
# 16.0    840
# 17.0    660
# 18.0    626
# 19.0    861
# 20.0    636
# 21.0    409
# 22.0     78
# 23.0     13
# Name: dep_time, dtype: int64

# %% [markdown]
# Así obtenemos el número de valores faltantes para todas las columnas. Como solamente nos interesan las de `dep_time`, modificamos nuestra petición

# %% [markdown]
# ## Para aplicar funciones diferentes a diferentes columnas:
# Hasta el momento, hemos obtenido los mismos indicadores para las diferentes columnas. Es posible especificar funciones diferentes para distintas columnas, usando un dictionario.

# %%
df.groupby("X").agg(
    {
        "Y": "describe",
        "Z": np.mean
    }
)
# Out:
# /tmp/ipykernel_31322/2887271895.py:1: FutureWarning: The provided callable <function mean at 0x7f80d0d49620> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("X").agg(
#       Y                                               Z
#   count mean       std  min   25%  50%   75%  max     Z
# X
# a   2.0  2.0  1.414214  1.0  1.50  2.0  2.50  3.0   9.5
# b   1.0  4.0       NaN  4.0  4.00  4.0  4.00  4.0  12.5
# c   2.0  6.5  0.707107  6.0  6.25  6.5  6.75  7.0  15.0

# %%
agrupados

# %%
df = pd.DataFrame(
    {
     "X": ['a', 'a', 'a', 'a', 'b', 'b', 'c', 'c'],
     "Y": np.arange(8),
     "Z": np.arange(8,16)
    }
)
df
# Out:
#    X  Y   Z
# 0  a  0   8
# 1  a  1   9
# 2  a  2  10
# 3  a  3  11
# 4  b  4  12
# 5  b  5  13
# 6  c  6  14
# 7  c  7  15

# %%
agrupados.transform(np.mean)
# Out:
# /tmp/ipykernel_31322/192761788.py:1: FutureWarning: The provided callable <function mean at 0x7f80d0d49620> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   agrupados.transform(np.mean)
#      Y     Z
# 0  1.5   9.5
# 1  1.5   9.5
# 2  1.5   9.5
# 3  1.5   9.5
# 4  4.5  12.5
# 5  4.5  12.5
# 6  6.5  14.5
# 7  6.5  14.5

# %%
df
# Out:
#    X  Y   Z
# 0  a  0   8
# 1  a  1   9
# 2  a  2  10
# 3  a  3  11
# 4  b  4  12
# 5  b  5  13
# 6  c  6  14
# 7  c  7  15

# %%
df_copy = df.copy()
df_copy[["mean_X", "media_Z"]] = df.groupby("X").transform(np.mean)
df_copy
# Out:
# /tmp/ipykernel_31322/4152674241.py:2: FutureWarning: The provided callable <function mean at 0x7f80d0d49620> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_copy[["mean_X", "media_Z"]] = df.groupby("X").transform(np.mean)
#    X  Y   Z  mean_X  media_Z
# 0  a  0   8     1.5      9.5
# 1  a  1   9     1.5      9.5
# 2  a  2  10     1.5      9.5
# 3  a  3  11     1.5      9.5
# 4  b  4  12     4.5     12.5
# 5  b  5  13     4.5     12.5
# 6  c  6  14     6.5     14.5
# 7  c  7  15     6.5     14.5

# %% [markdown]
# ### Normalizacion
# $(x - x.mean()) / x.std()$

# %%
df_copy = df.copy()
df_copy.groupby("X").transform(lambda x: (x - x.mean()) / x.std())
# Out:
#           Y         Z
# 0 -1.161895 -1.161895
# 1 -0.387298 -0.387298
# 2  0.387298  0.387298
# 3  1.161895  1.161895
# 4 -0.707107 -0.707107
# 5  0.707107  0.707107
# 6 -0.707107 -0.707107
# 7  0.707107  0.707107

# %%
df.loc[[0, 2, 5], 'Y'] = np.NaN
df.loc[6, 'Z'] = np.NaN
df
# Out:
#    X    Y     Z
# 0  a  NaN   8.0
# 1  a  1.0   9.0
# 2  a  NaN  10.0
# 3  a  3.0  11.0
# 4  b  4.0  12.0
# 5  b  NaN  13.0
# 6  c  6.0   NaN
# 7  c  7.0  15.0

# %%
# Es razonable sustituir los NaN por la mediana de la serie, para no alterar las estadisticas
df["Y"].where(~ df["Y"].isna(), 1000)
# Out:
# 0    1000.0
# 1       1.0
# 2    1000.0
# 3       3.0
# 4       4.0
# 5    1000.0
# 6       6.0
# 7       7.0
# Name: Y, dtype: float64

# %%
df.loc[[0, 2, 5], 'Y'] = np.NaN
df.loc[6, 'Z'] = np.NaN
df

df.groupby("X").transform(lambda x: x.where(x.notna(), x.median()))
# Out:
#      Y     Z
# 0  2.0   8.0
# 1  1.0   9.0
# 2  2.0  10.0
# 3  3.0  11.0
# 4  4.0  12.0
# 5  4.0  13.0
# 6  6.0  15.0
# 7  7.0  15.0
